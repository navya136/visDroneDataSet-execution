# %%
import cv2
import os
import numpy as np


input_img_folder = 'VisDrone2019-DET-val/images'
input_ann_folder = 'VisDrone2019-DET-val/annotations'
output_ann_folder = 'VisDrone2019-DET-val/xml_annotationss'
output_img_folder = 'VisDrone2019-DET-val/new_images'

os.makedirs(output_img_folder, exist_ok=True)
os.makedirs(output_ann_folder, exist_ok=True)


image_list = os.listdir(input_img_folder)
annotation_list = os.listdir(input_ann_folder)

label_dict = {
	"0" : "Ignore",
	"1" : "Pedestrian",
	"2" : "People",
	"3" : "Bicycle",
	"4" : "Car",
	"5" : "Van",
	"6" : "Truck",
	"7" : "Tricycle",
	"8" : "Awning-tricycle",
	"9" : "Bus",
	"10" : "Motor",
	"11" : "Others"
}

thickness = 2
color = (255,0,0)
count = 0

def object_string(label, bbox):
	req_str = '''
	<object>
		<name>{}</name>
		<pose>Unspecified</pose>
		<truncated>0</truncated>
		<difficult>0</difficult>
		<bndbox>
			<xmin>{}</xmin>
			<ymin>{}</ymin>
			<xmax>{}</xmax>
			<ymax>{}</ymax>
		</bndbox>
	</object>
	'''.format(label, bbox[0], bbox[1], bbox[2], bbox[3])
	return req_str

for annotation in annotation_list:
	annotation_path = os.path.join(os.getcwd(), input_ann_folder, annotation)
	xml_annotation = annotation.split('.txt')[0] + '.xml'
	xml_path = os.path.join(os.getcwd(), output_ann_folder, xml_annotation)
	img_file = annotation.split('.txt')[0] + '.jpg'
	img_path = os.path.join(os.getcwd(), input_img_folder, img_file)
	output_img_path = os.path.join(os.getcwd(), output_img_folder, img_file)
	img = cv2.imread(img_path)
	annotation_string_init = '''
<annotation>
	<folder>annotations</folder>
	<filename>{}</filename>
	<path>{}</path>
	<source>
		<database>Unknown</database>
	</source>
	<size>
		<width>{}</width>
		<height>{}</height>
		<depth>{}</depth>
	</size>
	<segmented>0</segmented>'''.format(img_file, img_path, img.shape[0], img.shape[1], img.shape[2])

	file = open(annotation_path, 'r')
	lines = file.readlines()
	for line in lines:
		new_line = line.strip('\n').split(',')
		new_coords_min = (int(new_line[0]), int(new_line[1]))
		new_coords_max = (int(new_line[0])+int(new_line[2]), int(new_line[1])+int(new_line[3]))
		bbox = (int(new_line[0]), int(new_line[1]), int(new_line[0])+int(new_line[2]), int(new_line[1])+int(new_line[3]))
		label = label_dict.get(new_line[5])
		req_str = object_string(label, bbox)
		annotation_string_init = annotation_string_init + req_str
		#cv2.rectangle(img, new_coords_min, new_coords_max, color, thickness)
	cv2.imwrite(output_img_path, img)
	annotation_string_final = annotation_string_init + '</annotation>'
	f = open(xml_path, 'w')
	f.write(annotation_string_final)
	f.close()
	count += 1
	print('[INFO] Completed {} image(s) and annotation(s) pair'.format(count))
# Out:
# [INFO] Completed 1 image(s) and annotation(s) pair
# [INFO] Completed 2 image(s) and annotation(s) pair
# [INFO] Completed 3 image(s) and annotation(s) pair
# [INFO] Completed 4 image(s) and annotation(s) pair
# [INFO] Completed 5 image(s) and annotation(s) pair
# [INFO] Completed 6 image(s) and annotation(s) pair
# [INFO] Completed 7 image(s) and annotation(s) pair
# [INFO] Completed 8 image(s) and annotation(s) pair
# [INFO] Completed 9 image(s) and annotation(s) pair
# [INFO] Completed 10 image(s) and annotation(s) pair
# [INFO] Completed 11 image(s) and annotation(s) pair
# [INFO] Completed 12 image(s) and annotation(s) pair
# [INFO] Completed 13 image(s) and annotation(s) pair
# [INFO] Completed 14 image(s) and annotation(s) pair
# [INFO] Completed 15 image(s) and annotation(s) pair
# [INFO] Completed 16 image(s) and annotation(s) pair
# [INFO] Completed 17 image(s) and annotation(s) pair
# [INFO] Completed 18 image(s) and annotation(s) pair
# [INFO] Completed 19 image(s) and annotation(s) pair
# [INFO] Completed 20 image(s) and annotation(s) pair
# [INFO] Completed 21 image(s) and annotation(s) pair
# [INFO] Completed 22 image(s) and annotation(s) pair
# [INFO] Completed 23 image(s) and annotation(s) pair
# [INFO] Completed 24 image(s) and annotation(s) pair
# [INFO] Completed 25 image(s) and annotation(s) pair
# [INFO] Completed 26 image(s) and annotation(s) pair
# [INFO] Completed 27 image(s) and annotation(s) pair
# [INFO] Completed 28 image(s) and annotation(s) pair
# [INFO] Completed 29 image(s) and annotation(s) pair
# [INFO] Completed 30 image(s) and annotation(s) pair
# [INFO] Completed 31 image(s) and annotation(s) pair
# [INFO] Completed 32 image(s) and annotation(s) pair
# [INFO] Completed 33 image(s) and annotation(s) pair
# [INFO] Completed 34 image(s) and annotation(s) pair
# [INFO] Completed 35 image(s) and annotation(s) pair
# [INFO] Completed 36 image(s) and annotation(s) pair
# [INFO] Completed 37 image(s) and annotation(s) pair
# [INFO] Completed 38 image(s) and annotation(s) pair
# [INFO] Completed 39 image(s) and annotation(s) pair
# [INFO] Completed 40 image(s) and annotation(s) pair
# [INFO] Completed 41 image(s) and annotation(s) pair
# [INFO] Completed 42 image(s) and annotation(s) pair
# [INFO] Completed 43 image(s) and annotation(s) pair
# [INFO] Completed 44 image(s) and annotation(s) pair
# [INFO] Completed 45 image(s) and annotation(s) pair
# [INFO] Completed 46 image(s) and annotation(s) pair
# [INFO] Completed 47 image(s) and annotation(s) pair
# [INFO] Completed 48 image(s) and annotation(s) pair
# [INFO] Completed 49 image(s) and annotation(s) pair
# [INFO] Completed 50 image(s) and annotation(s) pair
# [INFO] Completed 51 image(s) and annotation(s) pair
# [INFO] Completed 52 image(s) and annotation(s) pair
# [INFO] Completed 53 image(s) and annotation(s) pair
# [INFO] Completed 54 image(s) and annotation(s) pair
# [INFO] Completed 55 image(s) and annotation(s) pair
# [INFO] Completed 56 image(s) and annotation(s) pair
# [INFO] Completed 57 image(s) and annotation(s) pair
# [INFO] Completed 58 image(s) and annotation(s) pair
# [INFO] Completed 59 image(s) and annotation(s) pair
# [INFO] Completed 60 image(s) and annotation(s) pair
# [INFO] Completed 61 image(s) and annotation(s) pair
# [INFO] Completed 62 image(s) and annotation(s) pair
# [INFO] Completed 63 image(s) and annotation(s) pair
# [INFO] Completed 64 image(s) and annotation(s) pair
# [INFO] Completed 65 image(s) and annotation(s) pair
# [INFO] Completed 66 image(s) and annotation(s) pair
# [INFO] Completed 67 image(s) and annotation(s) pair
# [INFO] Completed 68 image(s) and annotation(s) pair
# [INFO] Completed 69 image(s) and annotation(s) pair
# [INFO] Completed 70 image(s) and annotation(s) pair
# [INFO] Completed 71 image(s) and annotation(s) pair
# [INFO] Completed 72 image(s) and annotation(s) pair
# [INFO] Completed 73 image(s) and annotation(s) pair
# [INFO] Completed 74 image(s) and annotation(s) pair
# [INFO] Completed 75 image(s) and annotation(s) pair
# [INFO] Completed 76 image(s) and annotation(s) pair
# [INFO] Completed 77 image(s) and annotation(s) pair
# [INFO] Completed 78 image(s) and annotation(s) pair
# [INFO] Completed 79 image(s) and annotation(s) pair
# [INFO] Completed 80 image(s) and annotation(s) pair
# [INFO] Completed 81 image(s) and annotation(s) pair
# [INFO] Completed 82 image(s) and annotation(s) pair
# [INFO] Completed 83 image(s) and annotation(s) pair
# [INFO] Completed 84 image(s) and annotation(s) pair
# [INFO] Completed 85 image(s) and annotation(s) pair
# [INFO] Completed 86 image(s) and annotation(s) pair
# [INFO] Completed 87 image(s) and annotation(s) pair
# [INFO] Completed 88 image(s) and annotation(s) pair
# [INFO] Completed 89 image(s) and annotation(s) pair
# [INFO] Completed 90 image(s) and annotation(s) pair
# [INFO] Completed 91 image(s) and annotation(s) pair
# [INFO] Completed 92 image(s) and annotation(s) pair
# [INFO] Completed 93 image(s) and annotation(s) pair
# [INFO] Completed 94 image(s) and annotation(s) pair
# [INFO] Completed 95 image(s) and annotation(s) pair
# [INFO] Completed 96 image(s) and annotation(s) pair
# [INFO] Completed 97 image(s) and annotation(s) pair
# [INFO] Completed 98 image(s) and annotation(s) pair
# [INFO] Completed 99 image(s) and annotation(s) pair
# [INFO] Completed 100 image(s) and annotation(s) pair
# [INFO] Completed 101 image(s) and annotation(s) pair
# [INFO] Completed 102 image(s) and annotation(s) pair
# [INFO] Completed 103 image(s) and annotation(s) pair
# [INFO] Completed 104 image(s) and annotation(s) pair
# [INFO] Completed 105 image(s) and annotation(s) pair
# [INFO] Completed 106 image(s) and annotation(s) pair
# [INFO] Completed 107 image(s) and annotation(s) pair
# [INFO] Completed 108 image(s) and annotation(s) pair
# [INFO] Completed 109 image(s) and annotation(s) pair
# [INFO] Completed 110 image(s) and annotation(s) pair
# [INFO] Completed 111 image(s) and annotation(s) pair
# [INFO] Completed 112 image(s) and annotation(s) pair
# [INFO] Completed 113 image(s) and annotation(s) pair
# [INFO] Completed 114 image(s) and annotation(s) pair
# [INFO] Completed 115 image(s) and annotation(s) pair
# [INFO] Completed 116 image(s) and annotation(s) pair
# [INFO] Completed 117 image(s) and annotation(s) pair
# [INFO] Completed 118 image(s) and annotation(s) pair
# [INFO] Completed 119 image(s) and annotation(s) pair
# [INFO] Completed 120 image(s) and annotation(s) pair
# [INFO] Completed 121 image(s) and annotation(s) pair
# [INFO] Completed 122 image(s) and annotation(s) pair
# [INFO] Completed 123 image(s) and annotation(s) pair
# [INFO] Completed 124 image(s) and annotation(s) pair
# [INFO] Completed 125 image(s) and annotation(s) pair
# [INFO] Completed 126 image(s) and annotation(s) pair
# [INFO] Completed 127 image(s) and annotation(s) pair
# [INFO] Completed 128 image(s) and annotation(s) pair
# [INFO] Completed 129 image(s) and annotation(s) pair
# [INFO] Completed 130 image(s) and annotation(s) pair
# [INFO] Completed 131 image(s) and annotation(s) pair
# [INFO] Completed 132 image(s) and annotation(s) pair
# [INFO] Completed 133 image(s) and annotation(s) pair
# [INFO] Completed 134 image(s) and annotation(s) pair
# [INFO] Completed 135 image(s) and annotation(s) pair
# [INFO] Completed 136 image(s) and annotation(s) pair
# [INFO] Completed 137 image(s) and annotation(s) pair
# [INFO] Completed 138 image(s) and annotation(s) pair
# [INFO] Completed 139 image(s) and annotation(s) pair
# [INFO] Completed 140 image(s) and annotation(s) pair
# [INFO] Completed 141 image(s) and annotation(s) pair
# [INFO] Completed 142 image(s) and annotation(s) pair
# [INFO] Completed 143 image(s) and annotation(s) pair
# [INFO] Completed 144 image(s) and annotation(s) pair
# [INFO] Completed 145 image(s) and annotation(s) pair
# [INFO] Completed 146 image(s) and annotation(s) pair
# [INFO] Completed 147 image(s) and annotation(s) pair
# [INFO] Completed 148 image(s) and annotation(s) pair
# [INFO] Completed 149 image(s) and annotation(s) pair
# [INFO] Completed 150 image(s) and annotation(s) pair
# [INFO] Completed 151 image(s) and annotation(s) pair
# [INFO] Completed 152 image(s) and annotation(s) pair
# [INFO] Completed 153 image(s) and annotation(s) pair
# [INFO] Completed 154 image(s) and annotation(s) pair
# [INFO] Completed 155 image(s) and annotation(s) pair
# [INFO] Completed 156 image(s) and annotation(s) pair
# [INFO] Completed 157 image(s) and annotation(s) pair
# [INFO] Completed 158 image(s) and annotation(s) pair
# [INFO] Completed 159 image(s) and annotation(s) pair
# [INFO] Completed 160 image(s) and annotation(s) pair
# [INFO] Completed 161 image(s) and annotation(s) pair
# [INFO] Completed 162 image(s) and annotation(s) pair
# [INFO] Completed 163 image(s) and annotation(s) pair
# [INFO] Completed 164 image(s) and annotation(s) pair
# [INFO] Completed 165 image(s) and annotation(s) pair
# [INFO] Completed 166 image(s) and annotation(s) pair
# [INFO] Completed 167 image(s) and annotation(s) pair
# [INFO] Completed 168 image(s) and annotation(s) pair
# [INFO] Completed 169 image(s) and annotation(s) pair
# [INFO] Completed 170 image(s) and annotation(s) pair
# [INFO] Completed 171 image(s) and annotation(s) pair
# [INFO] Completed 172 image(s) and annotation(s) pair
# [INFO] Completed 173 image(s) and annotation(s) pair
# [INFO] Completed 174 image(s) and annotation(s) pair
# [INFO] Completed 175 image(s) and annotation(s) pair
# [INFO] Completed 176 image(s) and annotation(s) pair
# [INFO] Completed 177 image(s) and annotation(s) pair
# [INFO] Completed 178 image(s) and annotation(s) pair
# [INFO] Completed 179 image(s) and annotation(s) pair
# [INFO] Completed 180 image(s) and annotation(s) pair
# [INFO] Completed 181 image(s) and annotation(s) pair
# [INFO] Completed 182 image(s) and annotation(s) pair
# [INFO] Completed 183 image(s) and annotation(s) pair
# [INFO] Completed 184 image(s) and annotation(s) pair
# [INFO] Completed 185 image(s) and annotation(s) pair
# [INFO] Completed 186 image(s) and annotation(s) pair
# [INFO] Completed 187 image(s) and annotation(s) pair
# [INFO] Completed 188 image(s) and annotation(s) pair
# [INFO] Completed 189 image(s) and annotation(s) pair
# [INFO] Completed 190 image(s) and annotation(s) pair
# [INFO] Completed 191 image(s) and annotation(s) pair
# [INFO] Completed 192 image(s) and annotation(s) pair
# [INFO] Completed 193 image(s) and annotation(s) pair
# [INFO] Completed 194 image(s) and annotation(s) pair
# [INFO] Completed 195 image(s) and annotation(s) pair
# [INFO] Completed 196 image(s) and annotation(s) pair
# [INFO] Completed 197 image(s) and annotation(s) pair
# [INFO] Completed 198 image(s) and annotation(s) pair
# [INFO] Completed 199 image(s) and annotation(s) pair
# [INFO] Completed 200 image(s) and annotation(s) pair
# [INFO] Completed 201 image(s) and annotation(s) pair
# [INFO] Completed 202 image(s) and annotation(s) pair
# [INFO] Completed 203 image(s) and annotation(s) pair
# [INFO] Completed 204 image(s) and annotation(s) pair
# [INFO] Completed 205 image(s) and annotation(s) pair
# [INFO] Completed 206 image(s) and annotation(s) pair
# [INFO] Completed 207 image(s) and annotation(s) pair
# [INFO] Completed 208 image(s) and annotation(s) pair
# [INFO] Completed 209 image(s) and annotation(s) pair
# [INFO] Completed 210 image(s) and annotation(s) pair
# [INFO] Completed 211 image(s) and annotation(s) pair
# [INFO] Completed 212 image(s) and annotation(s) pair
# [INFO] Completed 213 image(s) and annotation(s) pair
# [INFO] Completed 214 image(s) and annotation(s) pair
# [INFO] Completed 215 image(s) and annotation(s) pair
# [INFO] Completed 216 image(s) and annotation(s) pair
# [INFO] Completed 217 image(s) and annotation(s) pair
# [INFO] Completed 218 image(s) and annotation(s) pair
# [INFO] Completed 219 image(s) and annotation(s) pair
# [INFO] Completed 220 image(s) and annotation(s) pair
# [INFO] Completed 221 image(s) and annotation(s) pair
# [INFO] Completed 222 image(s) and annotation(s) pair
# [INFO] Completed 223 image(s) and annotation(s) pair
# [INFO] Completed 224 image(s) and annotation(s) pair
# [INFO] Completed 225 image(s) and annotation(s) pair
# [INFO] Completed 226 image(s) and annotation(s) pair
# [INFO] Completed 227 image(s) and annotation(s) pair
# [INFO] Completed 228 image(s) and annotation(s) pair
# [INFO] Completed 229 image(s) and annotation(s) pair
# [INFO] Completed 230 image(s) and annotation(s) pair
# [INFO] Completed 231 image(s) and annotation(s) pair
# [INFO] Completed 232 image(s) and annotation(s) pair
# [INFO] Completed 233 image(s) and annotation(s) pair
# [INFO] Completed 234 image(s) and annotation(s) pair
# [INFO] Completed 235 image(s) and annotation(s) pair
# [INFO] Completed 236 image(s) and annotation(s) pair
# [INFO] Completed 237 image(s) and annotation(s) pair
# [INFO] Completed 238 image(s) and annotation(s) pair
# [INFO] Completed 239 image(s) and annotation(s) pair
# [INFO] Completed 240 image(s) and annotation(s) pair
# [INFO] Completed 241 image(s) and annotation(s) pair
# [INFO] Completed 242 image(s) and annotation(s) pair
# [INFO] Completed 243 image(s) and annotation(s) pair
# [INFO] Completed 244 image(s) and annotation(s) pair
# [INFO] Completed 245 image(s) and annotation(s) pair
# [INFO] Completed 246 image(s) and annotation(s) pair
# [INFO] Completed 247 image(s) and annotation(s) pair
# [INFO] Completed 248 image(s) and annotation(s) pair
# [INFO] Completed 249 image(s) and annotation(s) pair
# [INFO] Completed 250 image(s) and annotation(s) pair
# [INFO] Completed 251 image(s) and annotation(s) pair
# [INFO] Completed 252 image(s) and annotation(s) pair
# [INFO] Completed 253 image(s) and annotation(s) pair
# [INFO] Completed 254 image(s) and annotation(s) pair
# [INFO] Completed 255 image(s) and annotation(s) pair
# [INFO] Completed 256 image(s) and annotation(s) pair
# [INFO] Completed 257 image(s) and annotation(s) pair
# [INFO] Completed 258 image(s) and annotation(s) pair
# [INFO] Completed 259 image(s) and annotation(s) pair
# [INFO] Completed 260 image(s) and annotation(s) pair
# [INFO] Completed 261 image(s) and annotation(s) pair
# [INFO] Completed 262 image(s) and annotation(s) pair
# [INFO] Completed 263 image(s) and annotation(s) pair
# [INFO] Completed 264 image(s) and annotation(s) pair
# [INFO] Completed 265 image(s) and annotation(s) pair
# [INFO] Completed 266 image(s) and annotation(s) pair
# [INFO] Completed 267 image(s) and annotation(s) pair
# [INFO] Completed 268 image(s) and annotation(s) pair
# [INFO] Completed 269 image(s) and annotation(s) pair
# [INFO] Completed 270 image(s) and annotation(s) pair
# [INFO] Completed 271 image(s) and annotation(s) pair
# [INFO] Completed 272 image(s) and annotation(s) pair
# [INFO] Completed 273 image(s) and annotation(s) pair
# [INFO] Completed 274 image(s) and annotation(s) pair
# [INFO] Completed 275 image(s) and annotation(s) pair
# [INFO] Completed 276 image(s) and annotation(s) pair
# [INFO] Completed 277 image(s) and annotation(s) pair
# [INFO] Completed 278 image(s) and annotation(s) pair
# [INFO] Completed 279 image(s) and annotation(s) pair
# [INFO] Completed 280 image(s) and annotation(s) pair
# [INFO] Completed 281 image(s) and annotation(s) pair
# [INFO] Completed 282 image(s) and annotation(s) pair
# [INFO] Completed 283 image(s) and annotation(s) pair
# [INFO] Completed 284 image(s) and annotation(s) pair
# [INFO] Completed 285 image(s) and annotation(s) pair
# [INFO] Completed 286 image(s) and annotation(s) pair
# [INFO] Completed 287 image(s) and annotation(s) pair
# [INFO] Completed 288 image(s) and annotation(s) pair
# [INFO] Completed 289 image(s) and annotation(s) pair
# [INFO] Completed 290 image(s) and annotation(s) pair
# [INFO] Completed 291 image(s) and annotation(s) pair
# [INFO] Completed 292 image(s) and annotation(s) pair
# [INFO] Completed 293 image(s) and annotation(s) pair
# [INFO] Completed 294 image(s) and annotation(s) pair
# [INFO] Completed 295 image(s) and annotation(s) pair
# [INFO] Completed 296 image(s) and annotation(s) pair
# [INFO] Completed 297 image(s) and annotation(s) pair
# [INFO] Completed 298 image(s) and annotation(s) pair
# [INFO] Completed 299 image(s) and annotation(s) pair
# [INFO] Completed 300 image(s) and annotation(s) pair
# [INFO] Completed 301 image(s) and annotation(s) pair
# [INFO] Completed 302 image(s) and annotation(s) pair
# [INFO] Completed 303 image(s) and annotation(s) pair
# [INFO] Completed 304 image(s) and annotation(s) pair
# [INFO] Completed 305 image(s) and annotation(s) pair
# [INFO] Completed 306 image(s) and annotation(s) pair
# [INFO] Completed 307 image(s) and annotation(s) pair
# [INFO] Completed 308 image(s) and annotation(s) pair
# [INFO] Completed 309 image(s) and annotation(s) pair
# [INFO] Completed 310 image(s) and annotation(s) pair
# [INFO] Completed 311 image(s) and annotation(s) pair
# [INFO] Completed 312 image(s) and annotation(s) pair
# [INFO] Completed 313 image(s) and annotation(s) pair
# [INFO] Completed 314 image(s) and annotation(s) pair
# [INFO] Completed 315 image(s) and annotation(s) pair
# [INFO] Completed 316 image(s) and annotation(s) pair
# [INFO] Completed 317 image(s) and annotation(s) pair
# [INFO] Completed 318 image(s) and annotation(s) pair
# [INFO] Completed 319 image(s) and annotation(s) pair
# [INFO] Completed 320 image(s) and annotation(s) pair
# [INFO] Completed 321 image(s) and annotation(s) pair
# [INFO] Completed 322 image(s) and annotation(s) pair
# [INFO] Completed 323 image(s) and annotation(s) pair
# [INFO] Completed 324 image(s) and annotation(s) pair
# [INFO] Completed 325 image(s) and annotation(s) pair
# [INFO] Completed 326 image(s) and annotation(s) pair
# [INFO] Completed 327 image(s) and annotation(s) pair
# [INFO] Completed 328 image(s) and annotation(s) pair
# [INFO] Completed 329 image(s) and annotation(s) pair
# [INFO] Completed 330 image(s) and annotation(s) pair
# [INFO] Completed 331 image(s) and annotation(s) pair
# [INFO] Completed 332 image(s) and annotation(s) pair
# [INFO] Completed 333 image(s) and annotation(s) pair
# [INFO] Completed 334 image(s) and annotation(s) pair
# [INFO] Completed 335 image(s) and annotation(s) pair
# [INFO] Completed 336 image(s) and annotation(s) pair
# [INFO] Completed 337 image(s) and annotation(s) pair
# [INFO] Completed 338 image(s) and annotation(s) pair
# [INFO] Completed 339 image(s) and annotation(s) pair
# [INFO] Completed 340 image(s) and annotation(s) pair
# [INFO] Completed 341 image(s) and annotation(s) pair
# [INFO] Completed 342 image(s) and annotation(s) pair
# [INFO] Completed 343 image(s) and annotation(s) pair
# [INFO] Completed 344 image(s) and annotation(s) pair
# [INFO] Completed 345 image(s) and annotation(s) pair
# [INFO] Completed 346 image(s) and annotation(s) pair
# [INFO] Completed 347 image(s) and annotation(s) pair
# [INFO] Completed 348 image(s) and annotation(s) pair
# [INFO] Completed 349 image(s) and annotation(s) pair
# [INFO] Completed 350 image(s) and annotation(s) pair
# [INFO] Completed 351 image(s) and annotation(s) pair
# [INFO] Completed 352 image(s) and annotation(s) pair
# [INFO] Completed 353 image(s) and annotation(s) pair
# [INFO] Completed 354 image(s) and annotation(s) pair
# [INFO] Completed 355 image(s) and annotation(s) pair
# [INFO] Completed 356 image(s) and annotation(s) pair
# [INFO] Completed 357 image(s) and annotation(s) pair
# [INFO] Completed 358 image(s) and annotation(s) pair
# [INFO] Completed 359 image(s) and annotation(s) pair
# [INFO] Completed 360 image(s) and annotation(s) pair
# [INFO] Completed 361 image(s) and annotation(s) pair
# [INFO] Completed 362 image(s) and annotation(s) pair
# [INFO] Completed 363 image(s) and annotation(s) pair
# [INFO] Completed 364 image(s) and annotation(s) pair
# [INFO] Completed 365 image(s) and annotation(s) pair
# [INFO] Completed 366 image(s) and annotation(s) pair
# [INFO] Completed 367 image(s) and annotation(s) pair
# [INFO] Completed 368 image(s) and annotation(s) pair
# [INFO] Completed 369 image(s) and annotation(s) pair
# [INFO] Completed 370 image(s) and annotation(s) pair
# [INFO] Completed 371 image(s) and annotation(s) pair
# [INFO] Completed 372 image(s) and annotation(s) pair
# [INFO] Completed 373 image(s) and annotation(s) pair
# [INFO] Completed 374 image(s) and annotation(s) pair
# [INFO] Completed 375 image(s) and annotation(s) pair
# [INFO] Completed 376 image(s) and annotation(s) pair
# [INFO] Completed 377 image(s) and annotation(s) pair
# [INFO] Completed 378 image(s) and annotation(s) pair
# [INFO] Completed 379 image(s) and annotation(s) pair
# [INFO] Completed 380 image(s) and annotation(s) pair
# [INFO] Completed 381 image(s) and annotation(s) pair
# [INFO] Completed 382 image(s) and annotation(s) pair
# [INFO] Completed 383 image(s) and annotation(s) pair
# [INFO] Completed 384 image(s) and annotation(s) pair
# [INFO] Completed 385 image(s) and annotation(s) pair
# [INFO] Completed 386 image(s) and annotation(s) pair
# [INFO] Completed 387 image(s) and annotation(s) pair
# [INFO] Completed 388 image(s) and annotation(s) pair
# [INFO] Completed 389 image(s) and annotation(s) pair
# [INFO] Completed 390 image(s) and annotation(s) pair
# [INFO] Completed 391 image(s) and annotation(s) pair
# [INFO] Completed 392 image(s) and annotation(s) pair
# [INFO] Completed 393 image(s) and annotation(s) pair
# [INFO] Completed 394 image(s) and annotation(s) pair
# [INFO] Completed 395 image(s) and annotation(s) pair
# [INFO] Completed 396 image(s) and annotation(s) pair
# [INFO] Completed 397 image(s) and annotation(s) pair
# [INFO] Completed 398 image(s) and annotation(s) pair
# [INFO] Completed 399 image(s) and annotation(s) pair
# [INFO] Completed 400 image(s) and annotation(s) pair
# [INFO] Completed 401 image(s) and annotation(s) pair
# [INFO] Completed 402 image(s) and annotation(s) pair
# [INFO] Completed 403 image(s) and annotation(s) pair
# [INFO] Completed 404 image(s) and annotation(s) pair
# [INFO] Completed 405 image(s) and annotation(s) pair
# [INFO] Completed 406 image(s) and annotation(s) pair
# [INFO] Completed 407 image(s) and annotation(s) pair
# [INFO] Completed 408 image(s) and annotation(s) pair
# [INFO] Completed 409 image(s) and annotation(s) pair
# [INFO] Completed 410 image(s) and annotation(s) pair
# [INFO] Completed 411 image(s) and annotation(s) pair
# [INFO] Completed 412 image(s) and annotation(s) pair
# [INFO] Completed 413 image(s) and annotation(s) pair
# [INFO] Completed 414 image(s) and annotation(s) pair
# [INFO] Completed 415 image(s) and annotation(s) pair
# [INFO] Completed 416 image(s) and annotation(s) pair
# [INFO] Completed 417 image(s) and annotation(s) pair
# [INFO] Completed 418 image(s) and annotation(s) pair
# [INFO] Completed 419 image(s) and annotation(s) pair
# [INFO] Completed 420 image(s) and annotation(s) pair
# [INFO] Completed 421 image(s) and annotation(s) pair
# [INFO] Completed 422 image(s) and annotation(s) pair
# [INFO] Completed 423 image(s) and annotation(s) pair
# [INFO] Completed 424 image(s) and annotation(s) pair
# [INFO] Completed 425 image(s) and annotation(s) pair
# [INFO] Completed 426 image(s) and annotation(s) pair
# [INFO] Completed 427 image(s) and annotation(s) pair
# [INFO] Completed 428 image(s) and annotation(s) pair
# [INFO] Completed 429 image(s) and annotation(s) pair
# [INFO] Completed 430 image(s) and annotation(s) pair
# [INFO] Completed 431 image(s) and annotation(s) pair
# [INFO] Completed 432 image(s) and annotation(s) pair
# [INFO] Completed 433 image(s) and annotation(s) pair
# [INFO] Completed 434 image(s) and annotation(s) pair
# [INFO] Completed 435 image(s) and annotation(s) pair
# [INFO] Completed 436 image(s) and annotation(s) pair
# [INFO] Completed 437 image(s) and annotation(s) pair
# [INFO] Completed 438 image(s) and annotation(s) pair
# [INFO] Completed 439 image(s) and annotation(s) pair
# [INFO] Completed 440 image(s) and annotation(s) pair
# [INFO] Completed 441 image(s) and annotation(s) pair
# [INFO] Completed 442 image(s) and annotation(s) pair
# [INFO] Completed 443 image(s) and annotation(s) pair
# [INFO] Completed 444 image(s) and annotation(s) pair
# [INFO] Completed 445 image(s) and annotation(s) pair
# [INFO] Completed 446 image(s) and annotation(s) pair
# [INFO] Completed 447 image(s) and annotation(s) pair
# [INFO] Completed 448 image(s) and annotation(s) pair
# [INFO] Completed 449 image(s) and annotation(s) pair
# [INFO] Completed 450 image(s) and annotation(s) pair
# [INFO] Completed 451 image(s) and annotation(s) pair
# [INFO] Completed 452 image(s) and annotation(s) pair
# [INFO] Completed 453 image(s) and annotation(s) pair
# [INFO] Completed 454 image(s) and annotation(s) pair
# [INFO] Completed 455 image(s) and annotation(s) pair
# [INFO] Completed 456 image(s) and annotation(s) pair
# [INFO] Completed 457 image(s) and annotation(s) pair
# [INFO] Completed 458 image(s) and annotation(s) pair
# [INFO] Completed 459 image(s) and annotation(s) pair
# [INFO] Completed 460 image(s) and annotation(s) pair
# [INFO] Completed 461 image(s) and annotation(s) pair
# [INFO] Completed 462 image(s) and annotation(s) pair
# [INFO] Completed 463 image(s) and annotation(s) pair
# [INFO] Completed 464 image(s) and annotation(s) pair
# [INFO] Completed 465 image(s) and annotation(s) pair
# [INFO] Completed 466 image(s) and annotation(s) pair
# [INFO] Completed 467 image(s) and annotation(s) pair
# [INFO] Completed 468 image(s) and annotation(s) pair
# [INFO] Completed 469 image(s) and annotation(s) pair
# [INFO] Completed 470 image(s) and annotation(s) pair
# [INFO] Completed 471 image(s) and annotation(s) pair
# [INFO] Completed 472 image(s) and annotation(s) pair
# [INFO] Completed 473 image(s) and annotation(s) pair
# [INFO] Completed 474 image(s) and annotation(s) pair
# [INFO] Completed 475 image(s) and annotation(s) pair
# [INFO] Completed 476 image(s) and annotation(s) pair
# [INFO] Completed 477 image(s) and annotation(s) pair
# [INFO] Completed 478 image(s) and annotation(s) pair
# [INFO] Completed 479 image(s) and annotation(s) pair
# [INFO] Completed 480 image(s) and annotation(s) pair
# [INFO] Completed 481 image(s) and annotation(s) pair
# [INFO] Completed 482 image(s) and annotation(s) pair
# [INFO] Completed 483 image(s) and annotation(s) pair
# [INFO] Completed 484 image(s) and annotation(s) pair
# [INFO] Completed 485 image(s) and annotation(s) pair
# [INFO] Completed 486 image(s) and annotation(s) pair
# [INFO] Completed 487 image(s) and annotation(s) pair
# [INFO] Completed 488 image(s) and annotation(s) pair
# [INFO] Completed 489 image(s) and annotation(s) pair
# [INFO] Completed 490 image(s) and annotation(s) pair
# [INFO] Completed 491 image(s) and annotation(s) pair
# [INFO] Completed 492 image(s) and annotation(s) pair
# [INFO] Completed 493 image(s) and annotation(s) pair
# [INFO] Completed 494 image(s) and annotation(s) pair
# [INFO] Completed 495 image(s) and annotation(s) pair
# [INFO] Completed 496 image(s) and annotation(s) pair
# [INFO] Completed 497 image(s) and annotation(s) pair
# [INFO] Completed 498 image(s) and annotation(s) pair
# [INFO] Completed 499 image(s) and annotation(s) pair
# [INFO] Completed 500 image(s) and annotation(s) pair
# [INFO] Completed 501 image(s) and annotation(s) pair
# [INFO] Completed 502 image(s) and annotation(s) pair
# [INFO] Completed 503 image(s) and annotation(s) pair
# [INFO] Completed 504 image(s) and annotation(s) pair
# [INFO] Completed 505 image(s) and annotation(s) pair
# [INFO] Completed 506 image(s) and annotation(s) pair
# [INFO] Completed 507 image(s) and annotation(s) pair
# [INFO] Completed 508 image(s) and annotation(s) pair
# [INFO] Completed 509 image(s) and annotation(s) pair
# [INFO] Completed 510 image(s) and annotation(s) pair
# [INFO] Completed 511 image(s) and annotation(s) pair
# [INFO] Completed 512 image(s) and annotation(s) pair
# [INFO] Completed 513 image(s) and annotation(s) pair
# [INFO] Completed 514 image(s) and annotation(s) pair
# [INFO] Completed 515 image(s) and annotation(s) pair
# [INFO] Completed 516 image(s) and annotation(s) pair
# [INFO] Completed 517 image(s) and annotation(s) pair
# [INFO] Completed 518 image(s) and annotation(s) pair
# [INFO] Completed 519 image(s) and annotation(s) pair
# [INFO] Completed 520 image(s) and annotation(s) pair
# [INFO] Completed 521 image(s) and annotation(s) pair
# [INFO] Completed 522 image(s) and annotation(s) pair
# [INFO] Completed 523 image(s) and annotation(s) pair
# [INFO] Completed 524 image(s) and annotation(s) pair
# [INFO] Completed 525 image(s) and annotation(s) pair
# [INFO] Completed 526 image(s) and annotation(s) pair
# [INFO] Completed 527 image(s) and annotation(s) pair
# [INFO] Completed 528 image(s) and annotation(s) pair
# [INFO] Completed 529 image(s) and annotation(s) pair
# [INFO] Completed 530 image(s) and annotation(s) pair
# [INFO] Completed 531 image(s) and annotation(s) pair
# [INFO] Completed 532 image(s) and annotation(s) pair
# [INFO] Completed 533 image(s) and annotation(s) pair
# [INFO] Completed 534 image(s) and annotation(s) pair
# [INFO] Completed 535 image(s) and annotation(s) pair
# [INFO] Completed 536 image(s) and annotation(s) pair
# [INFO] Completed 537 image(s) and annotation(s) pair
# [INFO] Completed 538 image(s) and annotation(s) pair
# [INFO] Completed 539 image(s) and annotation(s) pair
# [INFO] Completed 540 image(s) and annotation(s) pair
# [INFO] Completed 541 image(s) and annotation(s) pair
# [INFO] Completed 542 image(s) and annotation(s) pair
# [INFO] Completed 543 image(s) and annotation(s) pair
# [INFO] Completed 544 image(s) and annotation(s) pair
# [INFO] Completed 545 image(s) and annotation(s) pair
# [INFO] Completed 546 image(s) and annotation(s) pair
# [INFO] Completed 547 image(s) and annotation(s) pair
# [INFO] Completed 548 image(s) and annotation(s) pair

# %%
import glob
import os
import pickle
import xml.etree.ElementTree as ET
from os import listdir, getcwd
from os.path import join

dirs = ['./visDrone2019-DET-val/new_images']
classes = ["Pedestrian","People","Bicycle","Car", "Van","Truck", "Tricycle", "Awning-tricycle","Bus","Motor"]

def getImagesInDir(dir_path):
    image_list = []
    for filename in glob.glob(dir_path + '/*.jpg'):
        image_list.append(filename)

    return image_list

def convert(size, box):
    dw = 1./(size[0])
    dh = 1./(size[1])
    x = (box[0] + box[1])/2.0 - 1
    y = (box[2] + box[3])/2.0 - 1
    w = box[1] - box[0]
    h = box[3] - box[2]
    x = x*dw
    w = w*dw
    y = y*dh
    h = h*dh
    return (x,y,w,h)

def convert_annotation(dir_path, output_path, image_path):
    basename = os.path.basename(image_path)
    basename_no_ext = os.path.splitext(basename)[0]

    in_file = open(dir_path + '/' + basename_no_ext + '.xml')
    out_file = open(output_path + basename_no_ext + '.txt', 'w')
    tree = ET.parse(in_file)
    root = tree.getroot()
    size = root.find('size')
    w = int(size.find('width').text)
    h = int(size.find('height').text)

    for obj in root.iter('object'):
        difficult = obj.find('difficult').text
        cls = obj.find('name').text
        if cls not in classes or int(difficult)==1:
            continue
        cls_id = classes.index(cls)
        xmlbox = obj.find('bndbox')
        b = (float(xmlbox.find('xmin').text), float(xmlbox.find('xmax').text), float(xmlbox.find('ymin').text), float(xmlbox.find('ymax').text))
        bb = convert((w,h), b)
        out_file.write(str(cls_id) + " " + " ".join([str(a) for a in bb]) + '\n')

cwd = getcwd()

for dir_path in dirs:
    full_dir_path = cwd + '/' + dir_path
    output_path = full_dir_path +'/'

    if not os.path.exists(output_path):
        os.makedirs(output_path)

    image_paths = getImagesInDir(full_dir_path)
    list_file = open(full_dir_path + '.txt', 'w')

    for image_path in image_paths:
        list_file.write(image_path + '\n')
        convert_annotation(full_dir_path, output_path, image_path)
    list_file.close()

    print("Finished processing: " + dir_path)
# Out:
# Finished processing: ./visDrone2019-DET-val/new_images

# %% [markdown]
# # To split the dataset into two files 'train' and 'val'

# %%
import os
from random import choice
import shutil

#arrays to store file names
imgs =[]
xmls =[]

#setup dir names
trainPath = 'D:/AssignmentTextron/dataset/images/train'
valPath = 'D:/AssignmentTextron/dataset/images/val'
crsPath = 'D:/AssignmentTextron/New folder' #dir where images and annotations stored

#setup ratio (val ratio = rest of the files in origin dir after splitting into train and test)
train_ratio = 0.8
val_ratio = 0.2


#total count of imgs
totalImgCount = len(os.listdir(crsPath))/2

#soring files to corresponding arrays
for (dirname, dirs, files) in os.walk(crsPath):
    for filename in files:
        if filename.endswith('.txt'):
            xmls.append(filename)
        else:
            imgs.append(filename)


#counting range for cycles
countForTrain = int(len(imgs)*train_ratio)
countForVal = int(len(imgs)*val_ratio)
print("training images are : ",countForTrain)
print("Validation images are : ",countForVal)

# %%
trainimagePath = 'D:/AssignmentTextron/dataset/images/train'
trainlabelPath = 'D:/AssignmentTextron/dataset/labels/train'
valimagePath = 'D:/AssignmentTextron/dataset/images/val'
vallabelPath = 'D:/AssignmentTextron/dataset/labels/val'
#cycle for train dir
for x in range(countForTrain):

    fileJpg = choice(imgs) # get name of random image from origin dir
    fileXml = fileJpg[:-4] +'.txt' # get name of corresponding annotation file

    #move both files into train dir
    #shutil.move(os.path.join(crsPath, fileJpg), os.path.join(trainimagePath, fileJpg))
    #shutil.move(os.path.join(crsPath, fileXml), os.path.join(trainlabelPath, fileXml))
    shutil.copy(os.path.join(crsPath, fileJpg), os.path.join(trainimagePath, fileJpg))
    shutil.copy(os.path.join(crsPath, fileXml), os.path.join(trainlabelPath, fileXml))


    #remove files from arrays
    imgs.remove(fileJpg)
    xmls.remove(fileXml)



#cycle for test dir   
for x in range(countForVal):

    fileJpg = choice(imgs) # get name of random image from origin dir
    fileXml = fileJpg[:-4] +'.txt' # get name of corresponding annotation file

    #move both files into train dir
    #shutil.move(os.path.join(crsPath, fileJpg), os.path.join(valimagePath, fileJpg))
    #shutil.move(os.path.join(crsPath, fileXml), os.path.join(vallabelPath, fileXml))
    shutil.copy(os.path.join(crsPath, fileJpg), os.path.join(valimagePath, fileJpg))
    shutil.copy(os.path.join(crsPath, fileXml), os.path.join(vallabelPath, fileXml))
    
    #remove files from arrays
    imgs.remove(fileJpg)
    xmls.remove(fileXml)

#rest of files will be validation files, so rename origin dir to val dir
#os.rename(crsPath, valPath)
shutil.move(crsPath, valPath)
